# %% [markdown]
# # if-else formet

# %%
# if condition:
     print('condition one is true')
  elif condition:
     print('condition two is true')
  elif condition:
     print('condition third is true')
  else:
     print('all above condition is false')

# %%
if True:
    print('condition is true')
else:
    print('above condition is false')
# Out:
# condition is true

# %%
if False:
    print('condition is true')
else:
    print('above condition is false')
# Out:
# above condition is false

# %%
if 'a':
    print('condition is true')
elif'':
    print('condition is true')
elif'bhargav':
    print('condition is true me be false')
else:
    print('sab moh maya hei')
# Out:
# condition is true

# %%
if 'a':
    print('condition is false')
elif'':
    print('condition is true')
elif'bhargav':
    print('condition is also true but may be false')
else:
    print('sab moh maya hei')
# Out:
# condition is false

# %%
if'':
    print('condition is true')
elif'':
    print('condition is true')
elif False:
    print('condition is also true but may be false')
else:
    print('sab moh maya he')
# Out:
# sab moh maya he

# %%
inp = int(input('enter a number:'))
if inp%2 == 0:
    print('enter a number even')
else:
    print('enter a number odd')
# Out:
# enter a number:5
# enter a number odd

# %%
x=int(input('enter x number:'))
y=int(input('enter y number:'))
z=int(input('entar z number:'))
if x>y and x>z:
    print('x is big')
if y>z and y>x:
    print('y is big')
if z>x and z>y:
    print('z is big')
# Out:
# enter x number:56
# enter y number:78
# entar z number:95
# z is big

# %%
x=int(input('enter x number:'))
y=int(input('enter y number:'))
z=int(input('entar z number:'))
if x>=y and x>=z:
    print('x is largest',x)
elif y>=z:
    print('y is largest',y)
else:
    print('z is largest',z)
# Out:
# enter x number:85
# enter y number:52
# entar z number:46
# x is largest 85

# %%
inp = input('enter foo / bar:').lower().strip().replace('','')
if inp == 'foo':
    print('bar')
elif inp == 'bar':
    print('foo')
else:
    print('foo | bar')
# Out:
# enter foo / bar:              bhargav
# foo | bar

# %%
a = input('enter foo/bar:').lower().strip()
a = ''.join(a.split())
if a=='foo':
    print('bar')
elif a=='bar':
    print('foo')
else:
    print('foo | bar')
# Out:
# enter foo/bar:      bhargav
# foo | bar

# %%
a = 'hello world python ajay awesome'
b = a.split()
print(b)
# Out:
# ['hello', 'world', 'python', 'ajay', 'awesome']

# %%
' '.join(b)
# Out:
# 'hello world python ajay awesome'

# %%
inp = input('enter foo/bar:')
if inp.upper().replace(' ','') == 'FOO':
    print('bar')
elif inp.upper().repalce(' ','') == 'BAR':
    print('foo')
else:
    print('foo | bar')
# Out:
# enter foo/bar:foo
# bar

# %%
age=int(input('enter your age please:'))
if age>=18:
    print('congrate you are eligible loan')
    
    job=int(input('please enter your job proffesion:\n1.goverment\n2.private\n'))
    if job==1:
        print('high chance to get loan')
    elif job==2:
        print('low chance to get loan')
    else:
        print('please enter a valid choice')
        
else:
    print('sorry you are not eligible for loan')
# Out:
# enter your age please:21
# congrate you are eligible loan
# please enter your job proffesion:
# 1.goverment
# 2.private
# 1
# high chance to get loan
